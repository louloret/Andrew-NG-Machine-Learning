# %%
from IPython.display import Image
import sys
import numpy as np

# %%
path = "C:/Users/Luis/Anaconda3/"

# %% [markdown]
# ## Anomaly Detection

# %%
Image(filename =  path + "anomaly_detection.png")

# %%
Image(filename =  path + "anomaly_detection2.png")

# %%
Image(filename =  path + "anomaly_detection3.png")

# %%
# examples include fraud detection, users behaving strangely across a number
# of features such as logins, clicks or # of transactions

# %% [markdown]
# ### Gaussian Distribution

# %%
Image(filename =  path + "gaussian.png")

# %%
Image(filename =  path + "gaussian2.png")

# %%
Image(filename =  path + "gaussian3.png")

# %%
# we have a data that approaches normal distribution, but dont know parameters
#mu and sigma, we can estimate parameters through maximum likelihood

# %%
Image(filename =  path + "max_liklihood2.png")

# %%
# credit for pic above goes to following blog post
# https://towardsdatascience.com/probability-concepts-explained-maximum-likelihood-estimation-c7b4342fdbb1

# %%
Image(filename =  path + "density_estimation.png")

# %%
Image(filename =  path + "anomaly_detection4.png")

# %%
# likelihood of x(i) given parameters mu & sigma

# %%
Image(filename =  path + "anomaly_example.png")

# %%
# notice x1 & x2 have different mu and sigma parameters and consequently 
# different distributions

# p(x) = product of conditional x1 & x2 probabilities 

# how to choose epsilon?

# %%
Image(filename =  path + "developing.png")

# %%
Image(filename =  path + "developing2.png")

# %%
Image(filename =  path + "evaluation.png")

# %%
Image(filename =  path + "new_page.png")

# %%
Image(filename =  path + "anomaly_vs_world.png")

# %%
Image(filename =  path + "what_features.png")
