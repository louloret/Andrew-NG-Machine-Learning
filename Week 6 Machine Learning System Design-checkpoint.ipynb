# %%
from IPython.display import Image
import sys
import numpy as np

# %%
path = "C:/Users/Luis/Anaconda3/"

# %% [markdown]
# # Machine Learning System Design

# %% [markdown]
# ## Prioritizing what to work on

# %%
#spam classifier example

# %%
Image(filename =  path + "spam_classify.png")

# %%
# for supervised learning we need to determine our xs and ys

# %%
#determine what words are predictive of spam or not spam
# thinkgs like deal, discount

# %%
#now create a feature vector relative to these words where 1 if word shows up
# and 0 otherwise

# %%
Image(filename =  path + "spam2.png")

# %%
# in practice you usually pick the most frequently occuring words in training
# set, rather than manually picking 100 words

# %% [markdown]
# ### What is best use of time in order to minimize error?

# %%
Image(filename =  path + "spam3.png")

# %%
# beware of fixation on one of these options

# try out each option to see which gives best results

# do not go off gut feeling

# use error analysis as a systematic way to determine which option is most rewarding

# %%
Image(filename =  path + "priority.png")

# %% [markdown]
# ## Error Analysis

# %%
Image(filename =  path + "spam4.png")

# %%
# get something working quick! 

# get something that runs the first day and start testing with cross validation

# plot your learning curves of training and test errors and this will determine
# what next step is best

# this way we avoid premature optimization, let evidence dictate what we should
# optimize

# manually look at errors, see where there is room for opportunity

# %%
Image(filename =  path + "man_boost.png")

# %%
# manual boosting kind of

# %%
# features that can improve on classifying emails

# determine how many example have certain features, to conclude where to spend
# your time

# %%
Image(filename =  path + "features.png")

# %%
Image(filename =  path + "num_eval.png")

# %%
# with a numerical eval, you can test new ideas and see how it affects CV
# instead of manually going through all the examples you got wrong each time

# %%
# first quickly implement an algorithm ! and go from there
# use error analysis to inspire further development
# incorporate numerical evaluation to determine what ideas work and what does not

# %%
Image(filename =  path + "spam5.png")

# %% [markdown]
# ## Error Metrics for Skewed Classes

# %%
# in this case it is particularly tricky to come up with numerical evaluation
# for error

# %%
Image(filename =  path + "skewed.png")

# %%
# in this case a 1% error at first looks impressive, but turns out we would
# be better off predicting everyone does not have cancer and end up with a 
# 0.5% error rate

# %%
# an example would be a classifier that predicts 0 all the time would have
# recall of zero, indicating it probably is not a very good classifier

# %%
# precision vs. recall gives us more insight as to how well our algorithm is
# classifying, particularly for heavily skewed data

# %% [markdown]
# ## Trading Off Precision and Recall

# %%
Image(filename =  path + "spam7.png")

# %%
# how do we pick threshold automatically, in order to optimize and save time?

# %%
# picking the average between precision and recall is not a good option
Image(filename =  path + "spam8.png")

# %%
# in this case average is highest when we predict y =1 all the time even though
# that is not a particularly good classifier

# %%
# alternative way is using the F score. 
# combines precision and recall, and favors those that have both high precision
# and recall
Image(filename =  path + "spam9.png")

# %%
# you can also just use the area under the Precison vs. Recall curve
# this is probably most mathematically sound way of doing it
# even though F score seems to get you there as well
