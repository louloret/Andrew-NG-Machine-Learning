# %%
from IPython.display import Image
import sys
import numpy as np

# %%
path = "C:/Users/Luis/Anaconda3/"

# %% [markdown]
# ### Motivation behind Neural Nets

# %%
Image(filename = path + "motivation_behind_NeuralNets.png")

# %%
# non linear classifications do not scale well when we start adding 
# many features

# %%
Image(filename = path + "pixel_intensity.png")

# %%
Image(filename = path + "testing.png")

# %%
Image(filename = path + "too_many_features.png")

# %%
## we cluster similarity in pixel intesity across manny pixels between 
## cars and non cars and classify them

# %%
Image(filename = path + "Neurons.png")

# %%
# neuron sort of recieves imputs, and then computes output

# %%
Image(filename = path + "brain_communication.png")

# %%
# neurons communicating through pulses of electrcity

# %%
Image(filename = path + "neuron_model_logit.png")

# %%
#input wires = dendrites
# neuron is the yellow circle which does computation and gives output
# in this case the computation is the sigmoid function (activation function)
# where theta are our parameters/weights and x our features
# notice the activation function is just the sigmoid function
# is what adds non linearity to the model

# %%
Image(filename = path + "neural_net.png")

# %%
Image(filename = path + "neural_net_computation.png")

# %%
# notice how now we just have a series of sigmoid activation functions
# h substript theta of x is just culmination of the three sigmoid function with
#its own set of parameter or weights

# %%
Image(filename = path + "neural_net_quick_question.png")

# %%
Image(filename = path + "neural_net_answer.png")

# %%
Image(filename = path + "model_representation.png")

# %%
Image(filename = path + "model_representation2.png")

# %%
Image(filename = path + "vector_implementation.png")

# %%
Image(filename = path + "covering_features.png")

# %%
# if we cover features or input layer, we are back to good old 
# logistic regression!

#with 3 inputs, a set of parameters theta
#and an activation function = sigmoid function

# %%
Image(filename = path + "neural_net_learning.png")

# %%
# the  layer1 mapping to layer 2 is the neural net learning what features
# to use by applying a set of parameters theta 

#instead of it being constrained to its original inputs 
# (like logistic regression), it is learning its inputs from layer 1 to layer 2
# to allow for more complex features or inputs

# %%
Image(filename = path + "neural_net_question2.png")

# %%
Image(filename = path + "neural_net_answer2.png")

# %%
Image(filename = path + "model_representation3.png")

# %%
Image(filename = path + "model_representation4.png")

# %% [markdown]
# ## Neural Network Examples and Inuitions

# %%
## how neural networks can learn complex, non-linear hypothesis

# %%
Image(filename = path + "xnor_logic.png")

# %%
Image(filename = path + "logical_and_neuralnet.png")

# %%
Image(filename = path + "logical_or_neuralnet.png")

# %%
Image(filename = path + "examples_nd_intuitions1.png")
