# %% [markdown]
# # Unsupervised Learning

# %%
from IPython.display import Image
import sys
import numpy as np

# %%
path = "C:/Users/Luis/Anaconda3/"

# %%
Image(filename =  path + "kmeans.png")

# %%
Image(filename =  path + "supervised.png")

# %%
#supervised learning has label y --> difference between circles and xs

# %%
Image(filename =  path + "unsupervised.png")

# %%
# unsupervised has no y labels just xs
#all my exes live in texas :)

# %%
# ask algorithm to find structure in data for us

# %%
Image(filename =  path + "clustering.png")

# %%
#clustering algorithms find data point clusters in data

# %%
Image(filename =  path + "cluster_applications.png")

# %%
Image(filename =  path + "random_initialize.png")

# %%
# k- means is one of the more popular clustering algorithms

# %%
# first step is to randomly initialize k mean cluster centroids. We have 2 in
# this case because we want to group our data in 2 groups

# %%
# k means is an iterative algorithm that does 2 things
# first is cluster assignment and second is centroid move step

# %%
Image(filename =  path + "classify.png")

# %%
# after the assignment of centroid, each data point is classified based on 
# proximity to centroid cluster

# %%
# after this step, the centroids are moved in order to match the new means
# of the recent classification

# %%
Image(filename =  path + "move.png")

# %%
# this is done iteratively until the k means algorithm converges

# %%
Image(filename =  path + "move2.png")

# %%
Image(filename =  path + "move3.png")

# %%
# if we ran additional k means after this, the classifications would not change
# nor would the centroids. So the algorithm has completely converged

# %%
Image(filename =  path + "inputs.png")

# %%
# takes 2 inputs: K & xi

# %%
Image(filename =  path + "algo.png")

# %%
# first for loop classifies data points depending on which centroid is closest
# measuring distance from xi to uk & finding min value and set that as ci

# %%
Image(filename =  path + "algo2.png")

# %%
# second loop assigns cluster a new value based on the average for 
# the data points associated with that clusterz

# %%
# eliminate K means cluster if no data points are assigned to it

# %%
Image(filename =  path + "algo3.png")

# %%
# use k means for market segmentation
# design t shirts for 3 seperate populations

# %%
Image(filename =  path + "optimization_objective.png")

# %%
# knowing the optimization function will help us debug and find better clusters

# %%
Image(filename =  path + "cost_function_kmeans.png")

# %%
# capital K is all clusters, and lower case k is a specific cluster

# %%
# optimization function is trying to minimize the squared distance between
# xi and the cluster assigned to xi aka uc(i) by finding paremeters ci and uk
# that minimize that squared distance aka cost function J aka distortion of K 
# means algorithm

# %%
Image(filename =  path + "algo_opti.png")

# %%
# first step of algorithm aka cluster assignment step is actually picking the 
# ci or cluster index that minimizes the distance between xi and uc(i) aka the 
# cost function

# %%
Image(filename =  path + "second_step.png")

# %%
# second step aka move centroid step is using the values of u that minimize the
# cost function aka the squared distance between xi and uc(i)

# %%
Image(filename =  path + "iterations.png")

# %%
Image(filename =  path + "answer.png")

# %%
Image(filename =  path + "random_init.png")

# %%
Image(filename =  path + "random_pick_k.png")

# %%
# number of centroids K should be less than number of observations m

# %%
# randomly pick K training examples and randomly set them equal to any xi value

# %%
# However K means can end up at different solutions depending on how it is
# initially initialized

# %%
Image(filename =  path + "local_optima.png")

# %%
# not all local optima is a global optima

# %%
Image(filename =  path + "multi_rounds.png")

# %%
# in order to increase probability of cost function converging to global optima
# you can randomly initialize K clusters multiple times

# %%
# and then after just pick the clustering with lowest cost

# %%
# for K between 2 & 10 this will probably result in global optima cluster
# classification, but if K is very large, then having multiple random
# initializations is pretty useless and there is much higher chance that you 
# will achieve global optima with first initialization
