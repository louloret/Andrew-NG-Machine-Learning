# %%
from IPython.display import Image
import sys
import numpy as np

# %%
path= "C:/Users/Luis/Anaconda3/"

# %% [markdown]
# # Cost Function

# %%
Image(filename  = path + "NN_cost.png")

# %% [markdown]
# ## Neural Net cost function is generalization of regularized logistic regression

# %%
## neural net outputs vectors in Rk where k=1 in binary classfication problem

# %%
Image(filename  = path + "NN_cost_generalization.png")

# %%
## notice that we are summing the cost function over all k outputs

# %%
Image(filename  = path + "NN_cost_regularizationTerm.png")

# %%
## regularization term looks complicated but 
#all its doing is summing over theta ji for all values of i and j and L
#we dont sum over terms where i = 0 aka bias terms cause it doesnt make much of
# a difference

# %%
Image(filename  = path + "NN_cost_summary.png")

# %% [markdown]
# # Backpropagation

# %%
Image(filename  = path + "backprop_intro.png")

# %%
## finding weights theta that minimize cost function

# %% [markdown]
# ## Example: Starting with forward propagation for a 4 layer NN

# %%
Image(filename  = path + "forward_prop_example.png")

# %%
# remember the zs aka theta * x represent the dendrites or the links 
# from one layer to the next
# the as represent the neurons or the activation function of the 
# actual theta * x, aka the predictions aka the probabilities

# %% [markdown]
# ## Error terms

# %%
Image(filename  = path + "backprop_errors.png")

# %%
# where delta term is difference between hypothesis output and what was the 
# value of y

# %%
Image(filename  = path + "backprop_nextlayer.png")

# %%
# g prime of z3 is the derivative of activation function g aka
# sigmoid in this case, evaluated at the input values given by z3 ,
# g prime resolves to a3 dot times (1-a3). where a3 is vector of activations
# can do exact same thing for delta 2 term

# %%
# notice there is no delta 1 term, because first layer is just inputs
# and has no error associated with it

# %%
# derivation for back prop is suprisingly complicated and involved

# %%
Image(filename  = path + "backprop_proofish.png")

# %%
#but through these computation steps, it is possible to 
#prove an otherwise complex mathematical proof if you ignore the
# regularization term for now, then the partial deriv terms are given
# by the activation of these delta terms

# %%
Image(filename  = path + "back_prop_example.png")

# %%
Image(filename  = path + "backprop_summary.png")

# %%
Image(filename  = path + "backprop_summary2.png")

# %% [markdown]
# # Backpropagation Intuition

# %%
Image(filename  = path + "forward_prop_intuition.png")

# %%
# back prop is similar but instead of computations flowing form left to right
#they flow from right to left

# %%
Image(filename  = path + "backprop_doing_intuition.png")

# %%
#notice cost function looks just like logistic regression cost, 
# when we have one single output aka yi and no regularization term

# %%
Image(filename  = path + "backprop_partialderiv.png")

# %%
# back propagation is computing delta j  ^ l aka the error of cost
# for aj ^ l 

# more formally the delta terms are the partial derivatives with respect to 
# zj ^ l

#how much should we change neural networks weights in order to minimize
# cost function

# %%
Image(filename  = path + "step_by_step_backprop.png")

# %%
Image(filename  = path + "backprop_intuition_summary.png")
