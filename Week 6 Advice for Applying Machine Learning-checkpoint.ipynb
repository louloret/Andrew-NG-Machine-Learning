# %%
from IPython.display import Image
import sys
import numpy as np

# %%
path = "C:/Users/Luis/Anaconda3/"

# %% [markdown]
# # Evaluating a Learning Algorithm

# %% [markdown]
# #### Scenario where we are debugging an algorthim with high error rate

# %%
###### Typically tweaking optimizing lambda parameter is more effecient and
###### useful way of increasing accuracy of your model, more so than
###### collecting more training data, removing and adding features, or adding
###### polynomial features

# %%
Image(filename =  path + "debugging_algo.png")

# %%
Image(filename =  path + "diagnostic.png")

# %% [markdown]
# ## Evaluate Hypothesis

# %%
Image(filename =  path + "evaluate.png")

# %%
Image(filename =  path + "train_test.png")

# %%
## if data is sorted, we should take a random sample
## if data is randomly sorted than we are good

# %%
Image(filename =  path + "test_error.png")
# for linear regression

# %%
Image(filename =  path + "logistic_error.png")
# for logistic regression

# %%
# test error = fraction of test observations that are misclassified

# %%
Image(filename =  path + "evaluate_hypothesis_summary.png")

# %%
## the error of model should be based on how well model generalizes to unseen
## examples, in order to prevent overfitting
Image(filename =  path + "overfitting.png")

# %%
## lets say we are trying to choose what degree of polynomial we are trying
## to pick in order to optimize model on test set
Image(filename =  path + "d_to_test.png")

# %%
# because we have determined parameter d based on fit on test set
# it is no longer fair to evaluate generalization of model based on test set
# because we used this test set in order to determine best fit of d 
# so our weights were trained on it

# %%
# so instead of just train and test splits, we can add a third split: validation
# set in order to evaluate optimal parameters of models to generalize
# and then test parameters on test set
Image(filename =  path + "validation.png")

# %%
Image(filename =  path + "cost_equations.png")

# %%
# test parameters on cross validation set and pick model with lowest cross
# validation error, and then use the untouched test set in order to measure
# the generalization of the model

Image(filename =  path + "validate_nd_test.png")

# %%
Image(filename =  path + "model_selection_summary.png")
