# %% [markdown]
# # Support Vector Machines

# %% [markdown]
# ## Large Margin Classification

# %%
from IPython.display import Image
import sys
import numpy as np

# %%
path = "C:/Users/Luis/Anaconda3/"

# %%
Image(filename =  path + "support.png")
#support vector machines give you that elbow on the logistic regression cost
# function

# %%
# vector machine notational change
# removing 1/m
# multiplying by constant does not change minimum value
# Also changing regularization parameter
# should still give you same optimal value
Image(filename =  path + "support2.png")

# %%
# support vevctor machine does not output probability
# it outputs 1 or 0 directly
Image(filename =  path + "support3.png")
