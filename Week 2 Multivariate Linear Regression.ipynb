# %%
from IPython.display import Image
import sys
import numpy as np

# %%
path = "C://Users//Luis//Anaconda3/"

# %%
Image(filename = path + "multiple_features.png")

# %%
Image(filename = path + "gradient_descent_multi.png")

# %%
Image(filename = path + "scaling.png")
#faster convergence

# %%
Image(filename = path + "feature_scale.png")
#for faster convergence of gradient descent

# %%
Image(filename = path + "gradient_descent_debug.png")

# %%
Image(filename = path + "convergence.png")

# %%
Image(filename = path + "polynomial.png")
